# %% [markdown]
# 23. 다음과 같은 그래프가 주어졌다. 물음에 답하라.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (1). 이 그래프를 입접 행렬로 표현하라.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (2). 이 그래프를 인접 리스트로 표현하라.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (3). 정점 A를 출발 정점으로 하고 깊은 우선 방식으로 탐색하였을 때 방문하는 정점을 순서대로 나열하라. 단, 인접한 정점들 중에서는 알파벳으로 먼저 나오는 정점을 먼저 탐색한다고 가정하라.
#
# : ABCGFED
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (4). 위 문제에서 더 이상 방문하지 않은 인접 정점이 없어 첫 번째로 되돌아가는 정점을 찾아라.
#
# : D정점
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (5). 정점 A를 출발 정점으로 하고 너비 우선 방식으로 탐색하였을 때 방문하는 정점을 순서대로 나열하라. 단, 인접한 정점들 중에서는 알파벳으로 먼저 나오는 정점을 먼저 탐색한다고 가정하라.
#
# : ABDECFG
#
# ![image.png](attachment:image.png)
