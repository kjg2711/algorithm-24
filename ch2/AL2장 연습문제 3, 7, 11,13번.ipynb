# %% [markdown]
# 3) 다음의 두 알고리즘이 입력의 크기에 따라 어떤 증가 속도를 갖는지를 설명하고, 입력의 구성에 따라 처리시간이 달라지는지를 설명하라 .
#
# - (1) 입력 리스트에서 어떤 항목이 있는지를 검사하는 알고리즘
# - (2) 입력 리스트에서 어떤 항목이 몇 번 나타나는지를 구하는 알고리즘
#
#
#     - ![image.png](attachment:image.png)

# %% [markdown]
# 7) 다음의 빅오 표기법들을 실행 시간이 적게 걸리는 것부터 나열하라.
#
# - O(1) O(n) O(n2) O(n3) O(log n) O(n log n)  O(n!) O(2n2)
#
#     - `: O(1) O(log n) O(n) O(n log n) O(n2) O(n3) O(2n2)  O(n!)`

# %% [markdown]
# 11) 다음의 합을 구하라.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 13) 다음 알고리즘에 대해 물음에 답하라.
#
# ![image.png](attachment:image.png)
#
# - (1) 이 알고리즘의 용도를 설명하라. : 1부터 n까지 합하는 알고리즘
# - (2) 이 알고리즘에서 기본 연산을 찾아라. : sum = sum + i
# - (3) 기본연산이 몇 번 수행되어야 하는가? : n번
# - (4) 이 알고리즘의 복잡도를 설명하라. : O(n)
# - (5) 더 좋은 알고리즘이 있다면 제시하고, 복잡도를 설명하라. : O(1)
#
#
# - ![image-2.png](attachment:image-2.png)
#
# - ![image-3.png](attachment:image-3.png)
