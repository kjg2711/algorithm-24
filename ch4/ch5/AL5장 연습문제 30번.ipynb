# %% [markdown]
# 30) C언어에서 4바이트로 int를 표현하는데, 최대 231-1 까지 표현할 수 있다. 이 경우의 최대 피보나치 수를 구하라.
#
#
# - 피보나치 수열
# - F(46) = 1,836,311,903
# - F(47) = 2,971,215,073
#
#     - : 4바이트(32비트) 정수형 범위는 –2,147,483,648 ~ 2,147,483,647까지이다. 그러기 때문에 최대값 2,147,483,647을 초과하지 않는 최대의 피보나치 수인 46번째 F(46) = 1,836,311,903가 조건을 만족한다.
